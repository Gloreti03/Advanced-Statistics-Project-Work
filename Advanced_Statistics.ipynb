# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

sns.set(style="whitegrid", palette="tab10", rc={"figure.figsize": (6.4, 4.8)})
pd.set_option('display.max_columns', 100)

# %%
df = pd.read_csv("dataset.csv")

print("Shape:", df.shape)
df.info()
df.describe(include="all").T
# Out:
# Shape: (517754, 14)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517754 entries, 0 to 517753
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   id                      517754 non-null  int64
#  1   road_type               517754 non-null  object
#  2   num_lanes               517754 non-null  int64
#  3   curvature               517754 non-null  float64
#  4   speed_limit             517754 non-null  int64
#  5   lighting                517754 non-null  object
#  6   weather                 517754 non-null  object
#  7   road_signs_present      517754 non-null  bool
#  8   public_road             517754 non-null  bool
#  9   time_of_day             517754 non-null  object
#  10  holiday                 517754 non-null  bool
#  11  school_season           517754 non-null  bool
#  12  num_reported_accidents  517754 non-null  int64
#  13  accident_risk           517754 non-null  float64
# dtypes: bool(4), float64(2), int64(4), object(4)
# memory usage: 41.5+ MB
#                            count unique      top    freq       mean  \
# id                      517754.0    NaN      NaN     NaN   258876.5
# road_type                 517754      3  highway  173672        NaN
# num_lanes               517754.0    NaN      NaN     NaN   2.491511
# curvature               517754.0    NaN      NaN     NaN   0.488719
# speed_limit             517754.0    NaN      NaN     NaN  46.112575
# lighting                  517754      3      dim  183826        NaN
# weather                   517754      3    foggy  181463        NaN
# road_signs_present        517754      2    False  259289        NaN
# public_road               517754      2     True  260045        NaN
# time_of_day               517754      3  morning  173410        NaN
# holiday                   517754      2     True  260688        NaN
# school_season             517754      2    False  260164        NaN
# num_reported_accidents  517754.0    NaN      NaN     NaN    1.18797
# accident_risk           517754.0    NaN      NaN     NaN   0.352377
#
#                                   std   min        25%       50%        75%  \
# id                      149462.849975   0.0  129438.25  258876.5  388314.75
# road_type                         NaN   NaN        NaN       NaN        NaN
# num_lanes                    1.120434   1.0        1.0       2.0        3.0
# curvature                    0.272563   0.0       0.26      0.51       0.71
# speed_limit                 15.788521  25.0       35.0      45.0       60.0
# lighting                          NaN   NaN        NaN       NaN        NaN
# weather                           NaN   NaN        NaN       NaN        NaN
# road_signs_present                NaN   NaN        NaN       NaN        NaN
# public_road                       NaN   NaN        NaN       NaN        NaN
# time_of_day                       NaN   NaN        NaN       NaN        NaN
# holiday                           NaN   NaN        NaN       NaN        NaN
# school_season                     NaN   NaN        NaN       NaN        NaN
# num_reported_accidents       0.895961   0.0        1.0       1.0        2.0
# accident_risk                0.166417   0.0       0.23      0.34       0.46
#
#                              max
# id                      517753.0
# road_type                    NaN
# num_lanes                    4.0
# curvature                    1.0
# speed_limit                 70.0
# lighting                     NaN
# weather                      NaN
# road_signs_present           NaN
# public_road                  NaN
# time_of_day                  NaN
# holiday                      NaN
# school_season                NaN
# num_reported_accidents       7.0
# accident_risk                1.0

# %%
# Outlier detection

for col in num_features:
    sns.boxplot(x=df[col])
    plt.title(f"Outlier check: {col}")
    plt.show()

# %%
# Correlazioni e collinearità

corr = df[num_features].corr(method='pearson')
sns.heatmap(corr, cmap="coolwarm", center=0)
plt.title("Matrice di correlazione")
plt.show()
